# %%
import getpass

user = getpass.getuser()
from omni.isaac.kit import SimulationApp

# Set the path below to your desired nucleus server
simulation_app = SimulationApp(
    {"headless": True, "livesync_usd": f"omniverse://localhost/Users/{user}/temp_jupyter_stage.usd"}
)
print("Hi")
# Out:
# Starting kit application with the fillowing args:  ['/home/yizhou/.local/share/isaac_sim-2022.1.1/exts/omni.isaac.kit/omni/isaac/kit/simulation_app.py', '/home/yizhou/.local/share/isaac_sim-2022.1.1/apps/omni.isaac.sim.python.kit', '--/app/tokens/exe-path=/home/yizhou/.local/share/isaac_sim-2022.1.1/kit', '--/persistent/app/viewport/displayOptions=3094', '--/rtx/materialDb/syncLoads=True', '--/rtx/hydra/materialSyncLoads=True--/omni.kit.plugin/syncUsdLoads=True', '--/app/renderer/resolution/width=1280', '--/app/renderer/resolution/height=720', '--/app/window/width=1440', '--/app/window/height=900', '--/renderer/multiGpu/enabled=True', '--ext-folder', '/home/yizhou/.local/share/isaac_sim-2022.1.1/exts', '--ext-folder', '/home/yizhou/.local/share/isaac_sim-2022.1.1/apps', '--/physics/cudaDevice=0', '--portable', '--no-window']
# Passing the following args to the base kit application:  ['-f', '/home/yizhou/.local/share/jupyter/runtime/kernel-3ea44ab6-3fd5-4b43-8464-223da64581df.json']
# [Warning] [omni.kit.app.plugin] No crash reporter present, dumps uploading isn't available.
# [Info] [carb] Logging to file: /home/yizhou/.local/share/isaac_sim-2022.1.1/kit/logs/Kit/Isaac-Sim/2022.1/kit_20221011_112650.log
# 2022-10-11 18:26:50 s] [Warning] [omni.ext.plugin] [ext: omni.drivesim.sensors.nv.lidar] Extensions config 'extension.toml' doesn't exist '/home/yizhou/.local/share/isaac_sim-2022.1.1/exts/omni.drivesim.sensors.nv.lidar' or '/home/yizhou/.local/share/isaac_sim-2022.1.1/exts/omni.drivesim.sensors.nv.lidar/config'
# [0.094s] [ext: omni.stats-0.0.0] startup
# [0.126s] [ext: omni.gpu_foundation-0.0.0] startup
# 2022-10-11 18:26:50 s] [Warning] [carb] FrameworkImpl::setDefaultPlugin(client: omni.gpu_foundation_factory.plugin, desc : [carb::graphics::Graphics v2.5], plugin : carb.graphics-vulkan.plugin) failed. Plugin selection is locked, because the interface was previously acquired by:
# [0.131s] [ext: carb.windowing.plugins-1.0.0] startup
# [0.139s] [ext: omni.assets.plugins-0.0.0] startup
# [0.140s] [ext: omni.kit.renderer.init-0.0.0] startup
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 510.85.2      | Graphics API: Vulkan
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA RTX A6000                 | Yes: 0 |     | 49386   MB | 10de      | 0          |
# |     |                                  |        |     |            | 2230      | 48cf2a7a.. |
# |=============================================================================================|
# | OS: Linux yizhou-System-Product-Name, Version: 5.15.0-50-generic
# | Processor: 11th Gen Intel(R) Core(TM) i9-11900K @ 3.50GHz | Cores: Unknown | Logical: 16
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 31927 | Free Memory: 14909
# | Total Page/Swap (MB): 2047 | Free Page/Swap: 2047
# |---------------------------------------------------------------------------------------------|
# 2022-10-11 18:26:51 s] [Warning] [carb.cudainterop.plugin] On Linux only, CUDA and the display driver does not support IOMMU-enabled bare-metal PCIe peer to peer memory copy.
# However, CUDA and the display driver does support IOMMU via VM pass through. As a consequence, users on Linux,
# when running on a native bare metal system, should disable the IOMMU. The IOMMU should be enabled and the VFIO driver
# be used as a PCIe pass through for virtual machines.
# [0.815s] [ext: omni.kit.pipapi-0.0.0] startup
# [0.822s] [ext: omni.kit.pip_archive-0.0.0] startup
# [0.825s] [ext: omni.isaac.core_archive-1.2.0] startup
# [0.905s] [ext: omni.usd.config-1.0.0] startup
# [0.908s] [ext: omni.usd.libs-1.0.0] startup
# [0.995s] [ext: omni.kit.pip_torch-1_11_0-0.1.3] startup
# [1.017s] [ext: omni.isaac.ml_archive-1.1.0] startup
# [1.051s] [ext: omni.kit.loop-isaac-0.1.0] startup
# [1.051s] [ext: omni.kit.async_engine-0.0.0] startup
# [1.052s] [ext: omni.appwindow-1.0.0] startup
# [1.054s] [ext: omni.client-0.1.0] startup
# [1.061s] [ext: omni.kit.test-0.0.0] startup
# [1.062s] [ext: omni.kit.renderer.core-0.0.0] startup
# [1.122s] [ext: omni.ui-2.10.3] startup
# [1.136s] [ext: carb.audio-0.1.0] startup
# [1.154s] [ext: omni.kit.mainwindow-0.0.0] startup
# [1.156s] [ext: omni.uiaudio-1.0.0] startup
# [1.157s] [ext: omni.kit.uiapp-0.0.0] startup
# [1.157s] [ext: omni.usd.schema.physics-1.0.0] startup
# [1.190s] [ext: omni.usd.schema.audio-0.0.0] startup
# [1.195s] [ext: omni.usd.schema.semantics-0.0.0] startup
# [1.242s] [ext: omni.usd.schema.omnigraph-1.0.0] startup
# [1.249s] [ext: omni.usd.schema.anim-0.0.0] startup
# [1.279s] [ext: omni.kit.commands-1.2.2] startup
# [1.283s] [ext: omni.timeline-1.0.2] startup
# [1.285s] [ext: omni.hydra.scene_delegate-0.2.0] startup
# [1.289s] [ext: omn
# OmniAssetFileFormat
# i.kit.audiodeviceenum-1.0.0] startup
# [1.291s] [ext: omni.usd-1.5.3] startup
# [1.331s] [ext: omni.kit.asset_converter-1.2.31] startup
# [1.341s] [ext: omni.usd.schema.physx-0.0.0] startup
# [1.362s] [ext: omni.usd.schema.isaac-0.2.0] startup
# [1.393s] [ext: omni.usd.schema.forcefield-0.0.0] startup
# [1.400s] [ext: omni.kvdb-0.0.0] startup
# [1.402s] [ext: omni.usdphysics-1.4.15] startup
# [1.404s] [ext: omni.graph.tools-1.4.0] startup
# [1.422s] [ext: omni.localcache-0.0.0] startup
# [1.424s] [ext: omni.kit.stage_templates-1.1.2] startup
# [1.425s] [ext: omni.convexdecomposition-1.4.15] startup
# [1.427s] [ext: omni.physics.tensors-0.1.0] startup
# [1.433s] [ext: omni.physx-1.4.15-5.1] startup
# [1.448s] [ext: omni.graph.core-2.29.1] startup
# [1.452s] [ext: omni.kit.menu.utils-1.2.11] startup
# [1.461s] [ext: omni.physx.tensors-0.1.0] startup
# [1.466s] [ext: omni.graph-1.23.0] startup
# [1.505s] [ext: omni.kit.numpy.common-0.1.0] startup
# [1.508s] [ext: omni.kit.window.script_editor-1.6.2] startup
# [1.515s] [ext: omni.kit.search_core-1.0.2] startup
# [1.517s] [ext: omni.isaac.dynamic_control-1.1.0] startup
# [1.523s] [ext: omni.kit.renderer.capture-0.0.0] startup
# [1.526s] [ext: omni.kit.widget.filebrowser-2.2.27] startup
# [1.532s] [ext: omni.kit.widget.path_field-2.0.3] startup
# [1.533s] [ext: omni.kit.notification_manager-1.0.5] startup
# [1.535s] [ext: omni.kit.widget.versioning-1.3.8] startup
# [1.537s] [ext: omni.kit.widget.browser_bar-2.0.3] startup
# [1.538s] [ext: omni.kit.window.popup_dialog-2.0.8] startup
# [1.540s] [ext: omni.mdl.neuraylib-0.1.0] startup
# [1.542s] [ext: omni.kit.window.filepicker-2.4.30] startup
# Warp initialized:
#    Version: 0.2.2
#    CUDA device: NVIDIA RTX A6000
#    Kernel cache: /home/yizhou/.cache/warp/0.2.2
# [1.583s] [ext: omni.kit.menu.create-1.0.2] startup
# [1.584s] [ext: omni.mdl-0.1.0] startup
# [1.601s] [ext: omni.kit.window.file_importer-1.0.4] startup
# [1.602s] [ext: omni.kit.window.file_exporter-1.0.4] startup
# [1.602s] [ext: omni.kit.material.library-1.3.10] startup
# [1.605s] [ext: omni.kit.window.drop_support-1.0.0] startup
# [1.605s] [ext: omni.kit.window.file-1.3.16] startup
# [1.607s] [ext: omni.kit.context_menu-1.3.9] startup
# [1.658s] [ext: omni.kit.window.property-1.6.3] startup
# [1.659s] [ext: omni.kit.window.content_browser-2.4.28] startup
# [1.666s] [ext: omni.kit.widget.stage-2.6.15] startup
# [1.670s] [ext: omni.isaac.version-1.0.0] startup
# [1.670s] [ext: omni.kit.property.usd-3.14.9] startup
# [1.696s] [ext: omni.kit.viewport.legacy_gizmos-1.0.0] startup
# [1.698s] [ext: omni.hydra.rtx-0.1.0] startup
# [1.704s] [ext: omni.renderer-rtx-0.0.0] startup
# [1.705s] [ext: omni.hydra.engine.stats-1.0.0] startup
# [1.709s] [ext: omni.debugdraw-0.1.0] startup
# [1.713s] [ext: omni.kit.widget.settings-1.0.0] startup
# [1.714s] [ext: omni.kit.window.viewport-0.0.0] startup
# [2.651s] [ext: omni.kit.widget.prompt-1.0.1] startup
# [2.652s] [ext: omni.kit.widget.graph-1.4.3] startup
# [2.656s] [ext: omni.kit.window.preferences-1.2.1] startup
# [2.682s] [ext: omni.ui_query-1.1.1] startup
# [2.684s] [ext: omni.graph.ui-1.6.1] startup
# [2.701s] [ext: omni.kit.ui_test-1.2.2] startup
# [2.703s] [ext: omni.graph.action-1.18.0] startup
# [2.711s] [ext: omni.kit.widget.searchfield-1.0.6] startup
# [2.712s] [ext: omni.kit.usd_undo-0.1.0] startup
# [2.714s] [ext: omni.graph.scriptnode-0.5.0] startup
# [2.715s] [ext: omni.physx.commands-1.4.15-5.1] startup
# [2.719s] [ext: omni.graph.nodes-1.26.0] startup
# [2.730s] [ext: omni.command.usd-1.0.1] startup
# [2.732s] [ext: omni.kit.window.extensions-1.1.0] startup
# [2.736s] [ext: omni.syntheticdata-0.2.1] startup
# [2.764s] [ext: omni.kit.primitive.mesh-1.0.0] startup
# [2.767s] [ext: omni.warp-0.2.2] startup
# [3.286s] [ext: omni.isaac.ui-0.2.1] startup
# [3.288s] [ext: omni.replicator.core-1.4.3] startup
# [3.495s] [ext: omni.isaac.core-1.24.3] startup
# [3.564s] [ext: omni.physx.ui-1.4.15-5.1] startup
# [3.612s] [ext: omni.kit.property.material-1.8.5] startup
# [3.614s] [ext: omni.kit.window.toolbar-1.2.4] startup
# [3.619s] [ext: omni.isaac.core_nodes-0.13.0] startup
# [3.627s] [ext: omni.physx.demos-1.4.15-5.1] startup
# [3.630s] [ext: omni.kit.property.physx-0.1.0] startup
# 2022-10-11 18:26:54 [3,671ms] [Warning] [omni.physx.plugin] Deprecated: getSimulationEventStream is deprecated, please use getSimulationEventStreamV2
# [3.679s] [ext: omni.physx.tests-1.4.15-5.1] startup
# [3.846s] [ext: omni.isaac.wheeled_robots-0.5.8] startup
# [3.854s] [ext: omni.kit.menu.common-1.0.0] startup
# [3.855s] [ext: omni.physx.vehicle-1.4.15-5.1] startup
# [3.864s] [ext: omni.physx.cct-1.4.15-5.1] startup
# [3.939s] [ext: omni.physx.camera-1.4.15-5.1] startup
# [3.945s] [ext: omni.kit.widget.stage_icons-1.0.2] startup
# [3.946s] [ext: omni.ui.scene-1.5.0] startup
# [3.950s] [ext: omni.physx.bundle-1.4.15-5.1] startup
# [3.951s] [ext: omni.kit.window.stage-2.3.7] startup
# [3.953s] [ext: omni.replicator.composer-1.1.3] startup
# [3.965s] [ext: omni.isaac.lula-1.1.0] startup
# [3.974s] [ext: omni.rtx.window.settings-0.6.1] startup
# [3.978s] [ext: omni.isaac.surface_gripper-0.1.2] startup
# [3.982s] [ext: omni.isaac.motion_planning-0.2.0] startup
# [3.988s] [ext: omni.rtx.settings.core-0.5.5] startup
# [3.992s] [ext: omni.isaac.manipulators-1.0.1] startup
# [3.993s] [ext: omni.isaac.motion_generation-3.6.1] startup
# [3.997s] [ext: omni.kit.widget.zoombar-1.0.3] startup
# [3.997s] [ext: omni.kit.graph.delegate.default-1.0.15] startup
# [3.999s] [ext: omni.isaac.franka-0.3.0] startup
# [4.000s] [ext: omni.kit.browser.core-2.0.12] startup
# [4.004s] [ext: omni.kit.graph.editor.core-1.3.3] startup
# [4.006s] [ext: omni.kit.graph.usd.commands-1.1.0] startup
# [4.006s] [ext: omni.kit.browser.folder.core-1.1.13] startup
# [4.008s] [ext: omni.kit.graph.widget.variables-2.0.2] startup
# [4.009s] [ext: omni.kit.graph.delegate.modern-1.6.0] startup
# [4.011s] [ext: omni.kit.selection-0.1.0] startup
# [4.012s] [ext: omni.isaac.debug_draw-0.Saving a temp livesync stage at  omniverse://localhost/Users/yizhou/temp_jupyter_stage.usd  ...Done.
# Hi
